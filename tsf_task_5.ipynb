# %% [markdown]
# <a href="https://colab.research.google.com/github/dheep2305-git/Tsf-tasks/blob/main/tsf_task_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from statsmodels.datasets import get_rdataset
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Step 2: Load AirPassengers Dataset

data = get_rdataset("AirPassengers").data

# Extract passenger values
ts = data["value"]


# Step 3: Convert into Time Series Format

ts.index = pd.date_range(
    start="1949-01",
    periods=len(ts),
    freq="MS"
)


# Step 4: Plot Time Series

plt.figure(figsize=(10, 5))

plt.plot(ts)

plt.title("AirPassengers Time Series")

plt.xlabel("Time")
plt.ylabel("Passengers")

plt.show()


# Step 5: Plot ACF

plot_acf(ts, lags=30)

plt.title("Autocorrelation Function (ACF)")

plt.show()


# Step 6: Plot PACF

plot_pacf(ts, lags=30)

plt.title("Partial Autocorrelation Function (PACF)")

plt.show()

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git clone https://github.com/dheep2305-git/Tsf-tasks.git
# Out:
# Cloning into 'Tsf-tasks'...
# ...

# %%
# !ls
# Out:
# sample_data  Tsf-tasks
